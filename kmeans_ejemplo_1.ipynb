# %% [markdown]
# # Material de apoyo presentación

# %%
# --LLAMADO DE LIBRERIAS -------------------------------------------------------
import numpy as np                       # MANEJO DE ARRAYS
import matplotlib.pyplot as plt          # GRÁFICAS
from sklearn.datasets import make_blobs  # GENERAR DATOS DE EJEMPLO
from sklearn.cluster import KMeans       # ALGORITMO DE AGRUPAMIENTO
# ------------------------------------------------------------------------------

# Generar datos de ejemplo
data, _ = make_blobs(n_samples=300, centers=4, random_state=141)

# Crea el modelo K-Means con 4 clústeres
kmeans = KMeans(n_clusters=4)
kmeans.fit(data)

# Obtiene las etiquetas de los clústeres y los centroides para visualizarlos
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# --VISUALIZACIÓN DE LOS DATOS Y LOS CENTROIDES---------------------------------

# Ver los datos del color del cluster al que pertenece
plt.scatter(data[:, 0], data[:, 1], c='lightblue')

#  Coordenadas de los puntos "aleatorios"
p = [[-8, -8, 6, 3], [0, 2, 1, -5]]

# Dibujar los centroides
plt.scatter(p[0], p[1], marker='X', s=200, c='black')
plt.title('Clustering with K-Means')  # Pone el título al gráfico
plt.show()  # Mostrar gráfico
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# --LLAMADO DE LIBRERIAS -------------------------------------------------------
import numpy as np                       # MANEJO DE ARRAYS
import matplotlib.pyplot as plt          # GRÁFICAS
from sklearn.datasets import make_blobs  # GENERAR DATOS DE EJEMPLO
from sklearn.cluster import KMeans       # ALGORITMO DE AGRUPAMIENTO
# ------------------------------------------------------------------------------

# Generar datos de ejemplo
data, _ = make_blobs(n_samples=300, centers=4, random_state=141)

# Crea el modelo K-Means con 4 clústeres
kmeans = KMeans(n_clusters=4)
kmeans.fit(data)

# Obtiene las etiquetas de los clústeres y los centroides para visualizarlos
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# --VISUALIZACIÓN DE LOS DATOS Y LOS CENTROIDES---------------------------------

# Ver los datos del color del cluster al que pertenece
plt.scatter(data[:, 0], data[:, 1], c=labels, cmap="rainbow")

#  Coordenadas de los puntos "aleatorios"
p = [[-8, -8, 6, 3], [0, 2, 1, -5]]

# Dibujar los centroides
#plt.scatter(centroids[:, 0], centroids[:, 1], marker='X', s=200, c='black')
plt.scatter(p[0], p[1], marker='X', s=200, c='black')
plt.title('Clustering with K-Means')  # Pone el título al gráfico
plt.show()  # Mostrar gráfico
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# --LLAMADO DE LIBRERIAS -------------------------------------------------------
import numpy as np                       # MANEJO DE ARRAYS
import matplotlib.pyplot as plt          # GRÁFICAS
from sklearn.datasets import make_blobs  # GENERAR DATOS DE EJEMPLO
from sklearn.cluster import KMeans       # ALGORITMO DE AGRUPAMIENTO
# ------------------------------------------------------------------------------

# Generar datos de ejemplo
data, _ = make_blobs(n_samples=300, centers=4, random_state=141)

# Crea el modelo K-Means con 4 clústeres
kmeans = KMeans(n_clusters=4)
kmeans.fit(data)

# Obtiene las etiquetas de los clústeres y los centroides para visualizarlos
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# --VISUALIZACIÓN DE LOS DATOS Y LOS CENTROIDES---------------------------------

# Ver los datos del color del cluster al que pertenece
plt.scatter(data[:, 0], data[:, 1], c=labels, cmap="rainbow")

#  Coordenadas de los puntos "aleatorios"
p = [[-9, -9, 7, 4], [-1, 3, 0, -6]]

# Dibujar los centroides
#plt.scatter(centroids[:, 0], centroids[:, 1], marker='X', s=200, c='black')
plt.scatter(p[0], p[1], marker='X', s=200, c='black')
plt.title('Clustering with K-Means')  # Pone el título al gráfico
plt.show()  # Mostrar gráfico
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# --LLAMADO DE LIBRERIAS -------------------------------------------------------
import numpy as np                       # MANEJO DE ARRAYS
import matplotlib.pyplot as plt          # GRÁFICAS
from sklearn.datasets import make_blobs  # GENERAR DATOS DE EJEMPLO
from sklearn.cluster import KMeans       # ALGORITMO DE AGRUPAMIENTO
# ------------------------------------------------------------------------------

# Generar datos de ejemplo
data, _ = make_blobs(n_samples=300, centers=4, random_state=141)

# Crea el modelo K-Means con 4 clústeres
kmeans = KMeans(n_clusters=4)
kmeans.fit(data)

# Obtiene las etiquetas de los clústeres y los centroides para visualizarlos
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# --VISUALIZACIÓN DE LOS DATOS Y LOS CENTROIDES---------------------------------

# Ver los datos del color del cluster al que pertenece
plt.scatter(data[:, 0], data[:, 1], c=labels, cmap="rainbow")

#  Coordenadas de los puntos "aleatorios"
p = [[-9, -9, 8, 4], [-2, 4, 0, -7]]

# Dibujar los centroides
plt.scatter(centroids[:, 0], centroids[:, 1], marker='X', s=200, c='green')
plt.scatter(p[0], p[1], marker='X', s=200, c='black')
plt.title('Clustering with K-Means')  # Pone el título al gráfico
plt.show()  # Mostrar gráfico
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
